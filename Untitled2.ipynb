# %%
import pandas as pd
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]])
index = [1,2,3]
columns = ['a','b','c']
df

# %%
df = pd.read_csv('scores.csv')
df.columns
# Out:
# 이름     object
# 국어    float64
# 영어      int64
# 수학    float64
# dtype: object

# %%
df = pd.read_csv('scores.csv')
df.head(1)
# Out:
#      이름     국어  영어    수학
# 0  kate  100.0  90  95.0

# %%
df = pd.read_csv('scores.csv')
df.tail(1)
# Out:
#        이름    국어  영어    수학
# 10  james  70.0  75  65.0

# %%
df = pd.read_csv('scores.csv')
df.sample(n=3)
# Out:
#         이름    국어   영어     수학
# 2     emma  95.0  100  100.0
# 6   daniel  80.0   90   55.0
# 10   james  70.0   75   65.0

# %%
df = pd.read_csv('scores.csv')
len(df.columns)
# Out:
# 4

# %%
df = pd.read_csv('scores.csv')
df.columns[0]
# Out:
# '이름'

# %%
df = pd.read_csv('scores.csv')
df.nlargest(1,'영어')
# Out:
#      이름    국어   영어     수학
# 2  emma  95.0  100  100.0

# %%
df = pd.read_csv('scores.csv')
df.nsmallest(1,'영어')
# Out:
#     이름  국어  영어    수학
# 4  amy NaN  35  60.0

# %%
df = pd.read_csv('scores.csv')
df['이름']
# Out:
# 0       kate
# 1     olivia
# 2       emma
# 3     sophia
# 4        amy
# 5      james
# 6     daniel
# 7      peter
# 8      kevin
# 9       jack
# 10     james
# Name: 이름, dtype: object

# %%
df_lor = df[['이름','국어']]
df_lor.head(3)
# Out:
#        이름     국어
# 0    kate  100.0
# 1  olivia   90.0
# 2    emma   95.0

# %%
df = pd.read_csv('scores.csv')
df['국어']==100
# Out:
# 0      True
# 1     False
# 2     False
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# Name: 국어, dtype: bool

# %%
df = pd.read_csv('scores.csv')
df2 = df.set_index('이름')
df2
# Out:
#            국어   영어     수학
# 이름
# kate    100.0   90   95.0
# olivia   90.0   80   75.0
# emma     95.0  100  100.0
# sophia  100.0  100  100.0
# amy       NaN   35   60.0
# james    70.0   75   65.0
# daniel   80.0   90   55.0
# peter    50.0   60    NaN
# kevin   100.0  100   90.0
# jack     90.0   95   70.0
# james    70.0   75   65.0

# %%
df = pd.read_csv('scores.csv')
value = df.loc[0,'국어']
value
# Out:
# 100.0

# %%
df = pd.read_csv('scores.csv')
df2[(df2['영어']==35)]

# %%
value = df2.loc[['emma','peter'],'영어']
value
# Out:
# 이름
# emma     100
# peter     60
# Name: 영어, dtype: int64

# %%
import matplotlib.pyplot as plt
x = df['이름']
y = df['국어']

plt.bar(x,y,color = 'y',width = 0.3)
plt.show()

# %%
x = df['이름']
y1 = df['국어']
y2 = df['수학']
y3 = df['영어']

plt.scatter(x,y1)
plt.scatter(x,y2)
plt.scatter(x,y3)

plt.show()

# %%
df = pd.read_csv('ramen.csv')
df2 = df.set_index('구분')
df2['2004년':'2019년']
# Out:
#        신라면  진라면  삼양라면  안성탕면  너구리  육개장 사발면
# 구분
# 2004년   49    3    18    13    5        0
# 2014년   43    9    13     9    7        0
# 2019년   42   14    12    10    3        1

# %%
value = df2.loc['남성 30대','삼양라면']
value
# Out:
# 18

# %%
df2.loc['남성 30대',:]
# Out:
# 신라면        40
# 진라면        20
# 삼양라면       20
# 안성탕면        9
# 너구리         6
# 육개장 사발면     0
# Name: 남성 30대, dtype: int64

# %%
value = df2.loc[['남성 30대','여성 30대'],'진라면']
value
# Out:
# 구분
# 남성 30대    20
# 여성 30대    18
# Name: 진라면, dtype: int64

# %%
df2[(df2['안성탕면'])>=10]
# Out:
#            신라면  진라면  삼양라면  안성탕면  너구리  육개장 사발면
# 구분
# 남성 40대      45   17    17    11    1        3
# 남성 50대      44   12    12    12    1        2
# 여성 50대      50    8     8    13    2        1
# 여성 60대 이상   34   10    19    17    3        2
# 2004년       49    3    18    13    5        0
